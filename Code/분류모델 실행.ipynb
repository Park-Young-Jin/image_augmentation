# %%
#f = open("/content/drive/MyDrive/Colab Notebooks/졸업논문/실험결과/새파일.txt", 'w')
#f.close()

# %%
"aaaa"+str("aaaa")
# Out:
# 'aaaaaaaa'

# %%
seed = 42
random.seed(seed)
np.random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)  # type: ignore
torch.backends.cudnn.deterministic = True  # type: ignore
torch.backends.cudnn.benchmark = True  # type: ignore

# %%
# !pip install tensorboard_logger
# !pip3 install pickle5
# Out:
# ...
#      |████████████████████████████████| 256 kB 5.0 MB/s
# ...

# %%
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/졸업논문')

# %%
import PyramidNet

# %%
import train

# %%
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 4 --RandomHorizontalFlip 0 --RandomRotation 3 --RandomAffine 0

# %%
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 0 --RandomAffine 0
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 0 --RandomAffine 0.05
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 0 --RandomAffine 0.1
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 0 --RandomAffine 0.15
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 0 --RandomAffine 0.2
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 0 --RandomAffine 0.25
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 0 --RandomAffine 0.3
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 0 --RandomAffine 0.4
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 2 --RandomAffine 0
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 3 --RandomAffine 0
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 4 --RandomAffine 0
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 5 --RandomAffine 0
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 5 --RandomAffine 0.1
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 5 --RandomAffine 0.2
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 5 --RandomAffine 0.3
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 5 --RandomAffine 0.4
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 6 --RandomAffine 0
#!python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 7 --RandomAffine 0

# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 8 --RandomAffine 0
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 9 --RandomAffine 0
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 10 --RandomAffine 0
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 15 --RandomAffine 0
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 15 --RandomAffine 0.1
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 15 --RandomAffine 0.2
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 15 --RandomAffine 0.3
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 0 --RandomRotation 15 --RandomAffine 0.4

# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 1 --RandomRotation 0 --RandomAffine 0
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 1 --RandomRotation 0 --RandomAffine 0.1
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 1 --RandomRotation 0 --RandomAffine 0.2
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 1 --RandomRotation 0 --RandomAffine 0.3
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 1 --RandomRotation 0 --RandomAffine 0.4
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 1 --RandomRotation 5 --RandomAffine 0
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 1 --RandomRotation 5 --RandomAffine 0.1
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 1 --RandomRotation 5 --RandomAffine 0.2
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 1 --RandomRotation 5 --RandomAffine 0.3
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 1 --RandomRotation 5 --RandomAffine 0.4
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 1 --RandomRotation 15 --RandomAffine 0
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 1 --RandomRotation 15 --RandomAffine 0.1
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 1 --RandomRotation 15 --RandomAffine 0.2
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 1 --RandomRotation 15 --RandomAffine 0.3
# !python '/content/drive/MyDrive/Colab Notebooks/졸업논문/train.py' --net_type pyramidnet --alpha 64 --depth 110 --no-bottleneck --batch_size 64 --lr 0.025 --print-freq 1 --expname PyramidNet-110 --dataset cifar10 --epochs 2 --RandomHorizontalFlip 1 --RandomRotation 15 --RandomAffine 0.4
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch: [1/2][16/1563]	LR: 0.002500	Time 0.380 (0.396)	Data 0.000 (0.012)	Loss 0.3902 (0.6605)	Top 1-err 14.0625 (21.1397)	Top 5-err 14.0625 (21.1397)
# Epoch: [1/2][17/1563]	LR: 0.002500	Time 0.375 (0.395)	Data 0.000 (0.012)	Loss 0.7300 (0.6643)	Top 1-err 26.5625 (21.4410)	Top 5-err 26.5625 (21.4410)
# Epoch: [1/2][18/1563]	LR: 0.002500	Time 0.373 (0.394)	Data 0.000 (0.011)	Loss 0.6187 (0.6619)	Top 1-err 18.7500 (21.2993)	Top 5-err 18.7500 (21.2993)
# Epoch: [1/2][19/1563]	LR: 0.002500	Time 0.376 (0.393)	Data 0.000 (0.011)	Loss 0.5149 (0.6546)	Top 1-err 17.1875 (21.0938)	Top 5-err 17.1875 (21.0938)
# Epoch: [1/2][20/1563]	LR: 0.002500	Time 0.374 (0.392)	Data 0.000 (0.010)	Loss 0.6299 (0.6534)	Top 1-err 21.8750 (21.1310)	Top 5-err 21.8750 (21.1310)
# Epoch: [1/2][21/1563]	LR: 0.002500	Time 0.374 (0.391)	Data 0.000 (0.010)	Loss 0.5212 (0.6474)	Top 1-err 17.1875 (20.9517)	Top 5-err 17.1875 (20.9517)
# ...
